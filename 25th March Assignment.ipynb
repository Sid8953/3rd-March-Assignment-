# %% [markdown]
# #  Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
import pandas as pd

# %%
df = pd.read_excel('flight_price.xlsx')

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# This dataset have 10683 rows and 11 columns

# %% [markdown]
# # What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt


# Create a histogram of flight prices
sns.histplot(df, x='Price', bins=20, edgecolor='black')

# Add labels and title
plt.xlabel('Price')
plt.ylabel('Count')
plt.title('Distribution of Flight Prices')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 10
#       7 sns.histplot(df, x='Price', bins=20, edgecolor='black')
#       9 # Add labels and title
# ---> 10 plt.xlabel('Price')
#      11 plt.ylabel('Count')
#      12 plt.title('Distribution of Flight Prices')
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/_api/__init__.py:224, in caching_module_getattr.<locals>.__getattr__(name)
#     222 if name in props:
#     223     return props[name].__get__(instance)
# --> 224 raise AttributeError(
#     225     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'xlabel'

# %% [markdown]
# #  What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
import numpy as np
# Calculate the range, minimum, and maximum price using numpy
price_range = np.ptp(df["Price"])
min_price = np.min(df["Price"])
max_price = np.max(df["Price"])

# Print the results
print(f"The range of prices is {price_range}")
print(f"The minimum price is {min_price}")
print(f"The maximum price is {max_price}")
# Out:
# The range of prices is 77753
# The minimum price is 1759
# The maximum price is 79512

# %% [markdown]
# # How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.

# %%
# Create a boxplot of flight prices by airline using Seaborn
sns.boxplot(data=df, x='Airline', y='Price')

# Add labels and title
plt.xlabel('Airline')
plt.ylabel('Price')
plt.title('Flight Prices by Airline')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 5
#       2 sns.boxplot(data=df, x='Airline', y='Price')
#       4 # Add labels and title
# ----> 5 plt.xlabel('Airline')
#       6 plt.ylabel('Price')
#       7 plt.title('Flight Prices by Airline')
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/_api/__init__.py:224, in caching_module_getattr.<locals>.__getattr__(name)
#     222 if name in props:
#     223     return props[name].__get__(instance)
# --> 224 raise AttributeError(
#     225     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'xlabel'

# %% [markdown]
# # Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.
#
# Yes, there are outliers present in this dataset. The code is same as above.
#
# After creating the boxplot, we can look for any data points that fall outside the whiskers of the plot, which are typically considered potential outliers. These data points may impact our analysis by skewing the distribution of prices and affecting the accuracy of any statistical measures or models that we apply to the data.

# %% [markdown]
# # You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?
#
# 1.Month of Travel: We can analyze the distribution of flight prices by month to identify any patterns or trends in travel demand throughout the year. Typically, the peak season may coincide with holidays, festivals, or other events that are popular among travelers.
#
# 2.Airline: We can analyze the distribution of flight prices by airline to identify any differences in pricing strategies or demand among different airlines. Some airlines may offer discounts or promotions during the peak season to attract more customers, while others may raise their prices to take advantage of higher demand.
#
# 3.Departure and Arrival Cities: We can analyze the distribution of flight prices by departure and arrival cities to identify any popular destinations or routes that may experience higher demand during certain times of the year.
#
# 4.Duration of Stay: We can analyze the distribution of flight prices by the duration of stay to identify any preferences or trends among travelers. For example, some travelers may prefer shorter trips during the peak season to avoid high prices, while others may opt for longer vacations to take advantage of the favorable weather or events.
#
# Once we have identified the relevant features, we can present our findings to the boss using charts, graphs, and other visual aids that clearly illustrate the trends and patterns in the data. For example, we can create a line chart of flight prices by month to show the seasonal variations in demand, or a heat map of flight prices by departure and arrival cities to highlight the popular destinations during different times of the year. We can also use descriptive statistics, such as mean, median, and mode, to quantify the differences in prices and demand among different features. Ultimately, our goal is to provide the boss with actionable insights that can help the travel agency plan its operations and pricing strategies more effectively.

# %% [markdown]
# #  You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?
#
#
# 1.Date of Travel: We can analyze the distribution of flight prices by date to identify any patterns or trends in pricing over time. This can help us understand how prices fluctuate during different seasons, months, or weeks.
#
# 2.Flight Duration: We can analyze the distribution of flight prices by duration to identify any differences in pricing for shorter or longer flights. This can help us understand how airlines price their flights based on distance, time of day, or other factors.
#
# 3.Departure and Arrival Cities: We can analyze the distribution of flight prices by departure and arrival cities to identify any differences in pricing for different routes or regions. This can help us understand how demand and competition affect prices in different markets.
#
# 4.Airline: We can analyze the distribution of flight prices by airline to identify any differences in pricing strategies or market share among different airlines. This can help us understand how airlines compete on price and quality of service.
#
# Once we have identified the relevant features, we can use several visualizations to present our findings to the team, including:
#
# 1.Line Chart: We can create a line chart of flight prices by date to show the trends and patterns in pricing over time. This can help us identify any seasonal or cyclical trends in pricing.
#
# 2.Scatter Plot: We can create a scatter plot of flight prices by flight duration to identify any correlations or patterns in pricing for shorter or longer flights. This can help us understand how airlines price their flights based on distance or time of day.
#
# 3.Heat Map: We can create a heat map of flight prices by departure and arrival cities to identify any regional or local variations in pricing. This can help us understand how demand and competition affect prices in different markets.
#
# 4.Box Plot: We can create a box plot of flight prices by airline to identify any differences in pricing strategies or market share among different airlines. This can help us understand how airlines compete on price and quality of service.

# %% [markdown]
# #  You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?
#
#
# 1.Date of Travel: We can analyze the distribution of flight prices by date to identify any patterns or trends in pricing over time. This can help us understand how prices fluctuate during different seasons, months, or weeks.
#
# 2.Flight Duration: We can analyze the distribution of flight prices by duration to identify any differences in pricing for shorter or longer flights. This can help us understand how airlines price their flights based on distance, time of day, or other factors.
#
# Departure and Arrival Cities: We can analyze the distribution of flight prices by departure and arrival cities to identify any differences in pricing for different routes or regions. This can help us understand how demand and competition affect prices in different markets.
#
# Airline: We can analyze the distribution of flight prices by airline to identify any differences in pricing strategies or market share among different airlines. This can help us understand how airlines compete on price and quality of service.
#
# Advance Booking: We can analyze the distribution of flight prices by the time between booking and the departure date. This can help us understand how airlines price their flights based on the advance booking window.
#
# Seat Availability: We can analyze the distribution of flight prices by the seat availability for a particular flight. This can help us understand how airlines price their flights based on the remaining seats available.
#
# Once we have identified the relevant features, we can use several statistical and machine learning techniques to model the relationship between these factors and flight prices. We can use regression analysis to estimate the impact of each factor on flight prices and identify the factors that have the greatest impact on pricing.
#
# We can present our findings to the management team using visualizations such as scatter plots, heat maps, and bar charts to illustrate the relationship between different features and flight prices. We can also use statistical metrics such as correlation coefficients and p-values to quantify the strength and significance of these relationships.

# %% [markdown]
# # Load the Google Playstore dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# Thus this dataset have 10841 rows and 13 columns

# %% [markdown]
# # How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.

# %%
import matplotlib.pyplot as plt
# Filter out missing values in the 'Rating' and 'Category' columns
df = df.dropna(subset=['Rating', 'Category'])

# Create a boxplot of ratings by categor
sns.boxplot(x=df['Category'], y=df['Rating'])
plt.title('Distribution of App Ratings by Category')
plt.show()

# %% [markdown]
# # . Are there any missing values in the dataset? Identify any missing values and describe how they may impact your analysis.

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       4
# Android Ver       3
# dtype: int64

# %% [markdown]
# Missing values can impact our analysis in several ways. For example, if we are analyzing the relationship between app ratings and their category, missing values in the 'Rating' or 'Category' columns may lead to inaccurate conclusions or biased results. In such cases, we may need to drop the missing values or impute them with appropriate values based on the nature of the missing data.

# %% [markdown]
# # What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.

# %%
import matplotlib.pyplot as plt
# Filter out missing values in the 'Size' and 'Rating' columns
df = df.dropna(subset=['Size', 'Rating'])

# Create a scatter plot of Size vs Rating
plt.figure(figsize=(10, 6))
plt.scatter(x=df['Size'], y=df['Rating'], alpha=0.5)
plt.xlabel('Size (in MB)')
plt.ylabel('Rating')
plt.title('Relationship between App Size and Rating')
plt.show()

# %% [markdown]
# # How does the type of app affect its price? Create a bar chart to compare average prices by app type.
#
#
# The type of app can affect its price in various ways. Some app categories may have more demand than others, which could result in higher prices for those apps. For example, apps in the entertainment or gaming categories may be more in demand than apps in the education or productivity categories, which could lead to higher prices for the former.
#
# On the other hand, some app categories may have more competition than others, which could result in lower prices for those apps. For example, there may be many free apps available in the communication or social categories, which could make it difficult for paid apps in those categories to compete.
#
# By comparing the average prices of apps by category, we can gain insights into how the type of app affects its price. If we see that certain categories have consistently higher or lower prices than others, we can infer that the demand or competition in those categories is affecting the prices of the apps in those categories.
#
# A bar chart can be a useful way to visualize this data because it allows us to compare the average prices of apps in each category side-by-side. We can easily see which categories have the highest and lowest average prices, and identify any trends or patterns in the data.

# %% [markdown]
# # What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps with the highest number of installs.

# %%
# Creating a frequency table to show the number of apps in each install category
install_counts = df['Installs'].value_counts()

# Sorting the table by install counts in descending order
install_counts_sorted = install_counts.sort_values(ascending=False)

# Printing the top 10 most popular apps based on their number of installs
print(install_counts_sorted[:10])
# Out:
# 1,000,000+      1577
# 10,000,000+     1252
# 100,000+        1150
# 10,000+         1010
# 5,000,000+       752
# 1,000+           713
# 500,000+         538
# 50,000+          467
# 5,000+           432
# 100,000,000+     409
# Name: Installs, dtype: int64

# %% [markdown]
# #  A company wants to launch a new app on the Google Playstore and has asked you to analyze the Google Playstore dataset to identify the most popular app categories. How would you approach this task, and what features would you analyze to make recommendations to the company?
#
#
# 1.Identify the most common app categories by counting the number of apps in each category using the value_counts() function of pandas on the 'Category' column of the dataset.
#
# 2.Calculate the average rating and number of installs for each app category using the groupby() function of pandas.
#
# 3.Create visualizations such as bar charts and scatter plots to compare the popularity and user ratings of each app category.
#
# 4.Analyze any trends or patterns in the data to identify the most popular app categories.
#
# Based on this analysis, we can recommend the most popular app categories to the company and suggest any specific features or functionalities that are commonly found in these categories. For example, if we find that the entertainment or gaming categories are the most popular, we can recommend that the company focus on creating a highly engaging and interactive app that provides a fun and entertaining experience for users.
#
# In addition to the app category, we can also analyze other features such as the price, user reviews, and size of the apps to make recommendations to the company. For example, we can recommend that the company keep the app size as small as possible to improve the user experience and make it easier for users to download the app. We can also recommend a competitive pricing strategy based on the pricing trends for similar apps in the same category.

# %% [markdown]
# # A mobile app development company wants to analyze the Google Playstore dataset to identify the most successful app developers. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?
#
#
#
# Identify the app developers with the most number of apps on the Google Playstore dataset by counting the number of apps by each developer using the value_counts() function of pandas on the 'Developer' column of the dataset.
#
# Calculate the average rating and number of installs for each developer using the groupby() function of pandas.
#
# Create visualizations such as bar charts and scatter plots to compare the popularity and user ratings of each app developer.
#
# Analyze any trends or patterns in the data to identify the most successful app developers.
#
# Based on this analysis, we can recommend the most successful app developers to the company and suggest any specific features or functionalities that are commonly found in their apps. For example, if we find that a particular developer is known for creating highly engaging and interactive apps that provide a fun and entertaining experience for users, we can recommend that the company partner with that developer or hire them to create their own app.
#
# In addition to the app developer, we can also analyze other features such as the category, price, user reviews, and size of the apps to make recommendations to the company. For example, we can recommend that the company focus on creating apps in categories that are popular among the successful app developers, and price their apps competitively based on the pricing trends for similar apps in the same category.
#
# To present our findings, we can use data visualizations such as bar charts and scatter plots to highlight the most successful app developers and their apps. We can also use tables and graphs to show the number of apps, average rating, and number of installs for each app developer. This will help the company to easily understand the data and make informed decisions about their app development strategy.

# %% [markdown]
# # A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to launch a new app. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?
#
#
# 1.Analyze the trends in the number of app downloads and ratings over time using line charts and histograms to identify the months or days with the highest user engagement.
#
# 2.Identify the most popular app categories and their trends over time using stacked area charts or bar charts to determine the optimal time to launch a new app in a particular category.
#
# 3.Analyze the average rating and number of installs for apps launched during different months or days of the week to identify any patterns or trends.
#
# 4.Consider any seasonality or events that may impact user behavior and app usage, such as holidays, festivals, or sporting events.
#
# Based on this analysis, we can recommend the best time to launch a new app to the marketing research firm. For example, if we find that the summer months have the highest user engagement and the gaming category is the most popular, we can recommend launching a new gaming app during the summer months.
#
# In addition to the launch timing, we can also analyze other features such as the price, user reviews, and size of the apps to make recommendations to the company. For example, we can recommend that the company price their app competitively based on the pricing trends for similar apps in the same category, and keep the app size as small as possible to improve the user experience.
#
# To present our findings, we can use data visualizations such as line charts, stacked area charts, bar charts, and histograms to highlight the trends in app downloads, ratings, and category popularity over time. We can also use tables and graphs to show the average rating and number of installs for apps launched during different months or days of the week.
